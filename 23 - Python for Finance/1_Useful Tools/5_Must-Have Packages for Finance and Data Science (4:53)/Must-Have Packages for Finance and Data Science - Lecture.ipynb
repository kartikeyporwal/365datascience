# %%
import numpy

# %%
import pandas

# %%
import matplotlib

# %%
import math

# %%
import random

# %%
import statsmodels

# %%
import pandas_datareader
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-7-89e32976a845> in <module>()
# ----> 1 import pandas_datareader
#
# ImportError: No module named pandas_datareader

# %%
import pandas_datareader
