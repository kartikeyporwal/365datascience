# %%
import random

# %%
prob = random.random()
print prob
# Out:
# 0.102820103203

# %%
number = random.randint(1, 6)
print number
# Out:
# 5

# %%
import numpy as np

# %%
np.random.randint(1,6,(4,6))
# Out:
# array([[1, 3, 1, 4, 5, 3],
#        [5, 3, 2, 1, 5, 3],
#        [3, 1, 1, 3, 1, 1],
#        [4, 5, 1, 5, 5, 4]])
