# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

# %%
tickers = ['^GSPC', '^IXIC', '^GDAXI']

ind_data = pd.DataFrame()

for t in tickers:
    ind_data[t] = wb.DataReader(t, data_source='yahoo', start='1997-1-1')['Adj Close']

# %%
ind_data.head()
# Out:
#                  ^GSPC        ^IXIC       ^GDAXI
# Date
# 1997-01-02  737.010010  1280.699951  2820.810059
# 1997-01-03  748.030029  1310.680054  2863.260010
# 1997-01-06  747.650024  1316.400024  2890.199951
# 1997-01-07  753.229980  1327.729980  2876.340088
# 1997-01-08  748.409973  1320.349976  2904.080078

# %%
ind_data.tail()
# Out:
#                   ^GSPC        ^IXIC        ^GDAXI
# Date
# 2019-01-29  2640.000000  7028.290039  11218.830078
# 2019-01-30  2681.050049  7183.080078  11181.660156
# 2019-01-31  2704.100098  7281.740234  11173.099609
# 2019-02-01  2706.530029  7263.870117  11180.660156
# 2019-02-05  2731.760010  7385.410645  11358.719727

# %%
(ind_data / ind_data.iloc[0] * 100).plot(figsize=(15, 6));
plt.show()

# %%
ind_returns = (ind_data / ind_data.shift(1)) - 1

ind_returns.tail()
# Out:
#                ^GSPC     ^IXIC    ^GDAXI
# Date
# 2019-01-29 -0.001456 -0.008099  0.000760
# 2019-01-30  0.015549  0.022024 -0.003313
# 2019-01-31  0.008597  0.013735 -0.000766
# 2019-02-01  0.000899 -0.002454  0.000677
# 2019-02-05  0.009322  0.016732  0.015926

# %%
annual_ind_returns = ind_returns.mean() * 250
annual_ind_returns
# Out:
# ^GSPC     0.077061
# ^IXIC     0.110018
# ^GDAXI    0.076298
# dtype: float64

# %% [markdown]
# ***

# %%
tickers = ['PG', '^GSPC', '^DJI']

data_2 = pd.DataFrame()

for t in tickers:
    data_2[t] = wb.DataReader(t, data_source='yahoo', start='2007-1-1')['Adj Close']

# %%
data_2.tail()
# Out:
#                    PG        ^GSPC          ^DJI
# Date
# 2019-01-29  93.540001  2640.000000  24579.960938
# 2019-01-30  94.519997  2681.050049  25014.859375
# 2019-01-31  96.470001  2704.100098  24999.669922
# 2019-02-01  97.470001  2706.530029  25063.890625
# 2019-02-05  97.769997  2731.669922  25363.470703

# %%
(data_2 / data_2.iloc[0] * 100).plot(figsize=(15, 6));
plt.show()
