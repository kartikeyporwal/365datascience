# %% [markdown]
# ## Calculating the Return of Indices

# %% [markdown]
# *Suggested Answers follow (usually there are multiple ways to solve a problem in Python).*

# %% [markdown]
# Consider three famous American market indices – Dow Jones, S&P 500, and the Nasdaq for the period of 1st of January 2000 until today.

# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

# %%
tickers = ['^DJI', '^GSPC', '^IXIC']

ind_data = pd.DataFrame()

for t in tickers:
    ind_data[t] = wb.DataReader(t, data_source='yahoo', start='2000-1-1')['Adj Close']

# %%
ind_data.head()
# Out:
#                     ^DJI        ^GSPC        ^IXIC
# Date
# 2000-01-03  11357.509766  1455.219971  4131.149902
# 2000-01-04  10997.929688  1399.420044  3901.689941
# 2000-01-05  11122.650391  1402.109985  3877.540039
# 2000-01-06  11253.259766  1403.449951  3727.129883
# 2000-01-07  11522.559570  1441.469971  3882.620117

# %%
ind_data.tail()
# Out:
#                     ^DJI        ^GSPC        ^IXIC
# Date
# 2019-01-29  24579.960938  2640.000000  7028.290039
# 2019-01-30  25014.859375  2681.050049  7183.080078
# 2019-01-31  24999.669922  2704.100098  7281.740234
# 2019-02-01  25063.890625  2706.530029  7263.870117
# 2019-02-05  25363.509766  2731.459961  7384.169922

# %% [markdown]
# Normalize the data to 100 and plot the results on a graph.

# %%
(ind_data / ind_data.iloc[0] * 100).plot(figsize=(15, 6));
plt.show()

# %% [markdown]
# How would you explain the common and the different parts of the behavior of the three indices?

# %% [markdown]
# *****

# %% [markdown]
# Obtain the simple returns of the indices.

# %%
ind_returns = (ind_data / ind_data.shift(1)) - 1

ind_returns.tail()
# Out:
#                 ^DJI     ^GSPC     ^IXIC
# Date
# 2019-01-29  0.002109 -0.001456 -0.008099
# 2019-01-30  0.017693  0.015549  0.022024
# 2019-01-31 -0.000607  0.008597  0.013735
# 2019-02-01  0.002569  0.000899 -0.002454
# 2019-02-05  0.011954  0.009211  0.016561

# %% [markdown]
# Estimate the average annual return of each index.

# %%
annual_ind_returns = ind_returns.mean() * 250
annual_ind_returns
# Out:
# ^DJI     0.058006
# ^GSPC    0.050986
# ^IXIC    0.061657
# dtype: float64
