# %% [markdown]
# ## Monte Carlo - Predicting Gross Profit - Part II

# %% [markdown]
# *Suggested Answers follow (usually there are multiple ways to solve a problem in Python).*

# %% [markdown]
# Proceed from where we left off on the previous exercise.

# %%
import numpy as np
import matplotlib.pyplot as plt

rev_m = 200
rev_stdev = 10
iterations = 256

rev = np.random.normal(rev_m, rev_stdev, iterations)
COGS = - (rev * np.random.normal(0.4,0.2))

COGS.mean(), COGS.std()
# Out:
# (-29.438323606665847, 1.4008060656610366)

# %% [markdown]
# ****

# %% [markdown]
# Based on the predicted revenue and Cogs values, estimate the expected Gross Profit of your company.

# %% [markdown]
# *Reminder: Be careful about estimating the gross profit. If you have stored the Cogs value as a negative number, the gross profit will equal revenues plus Cogs. If you have created Cogs as a positive value, then gross profit would be equal to revenues minus Cogs. Either way, you will obtain the same result for gross profit.*

# %%
Gross_Profit = rev + COGS
Gross_Profit
# Out:
# array([ 170.87783448,  166.98489975,  165.21428332,  164.11165827,
#         167.37097261,  153.23857424,  182.71817032,  172.16376367,
#         159.50857927,  162.13480039,  172.40613146,  164.60050692,
#         149.50548714,  168.37098799,  174.88589595,  165.45014791,
#         173.18316875,  175.2373396 ,  166.5575287 ,  176.87182511,
#         177.75454466,  155.1133495 ,  158.42829941,  156.25482297,
#         160.6819267 ,  164.83583434,  178.71873501,  166.38979587,
#         163.70946619,  166.47498805,  173.8617523 ,  153.99519589,
#         164.6865888 ,  172.77494138,  175.63464318,  180.68154096,
#         163.02762335,  157.60541154,  174.43250943,  164.17703337,
#         173.13025614,  171.08785458,  182.56296125,  172.50146891,
#         182.83997846,  184.30674414,  172.4853657 ,  158.14056412,
#         167.42432358,  190.89406005,  163.37034736,  176.22478276,
#         174.86790225,  163.82358564,  162.69781622,  164.28364738,
#         163.65221976,  185.3691139 ,  170.48512461,  178.79494324,
#         171.48982142,  158.74498722,  164.31256306,  168.19858929,
#         184.49118288,  172.86248832,  176.79068286,  167.33060329,
#         179.55524506,  164.24963527,  186.68538943,  163.51749223,
#         165.71426016,  171.6462222 ,  183.91808866,  160.29938349,
#         171.96917721,  183.3186187 ,  181.93635235,  162.66505138,
#         177.18209114,  168.02457685,  162.68902929,  162.62621381,
#         171.46602955,  167.72060024,  182.85067377,  161.74098857,
#         170.85318485,  168.73361209,  171.98607549,  171.53747917,
#         171.08939428,  159.76235818,  171.73714139,  173.77074447,
#         161.84355022,  163.59109315,  169.65211345,  159.9392446 ,
#         162.58864737,  164.45980502,  176.50550745,  183.74095009,
#         161.26967034,  175.43558227,  176.32046617,  168.74447479,
#         175.15936729,  180.7494983 ,  170.31656231,  176.38843467,
#         170.40758987,  175.84528452,  163.301968  ,  174.45314049,
#         179.0743448 ,  178.90394198,  168.82173319,  175.3359927 ,
#         181.94457608,  164.76852634,  164.59604026,  176.0665326 ,
#         166.27302413,  167.41934274,  160.66670265,  157.8914167 ,
#         167.35040865,  176.79356276,  182.92376727,  176.84943777,
#         170.30664302,  168.76200568,  177.12696194,  165.66680253,
#         165.73483939,  171.91174276,  185.54922847,  154.87028769,
#         164.63070009,  156.363566  ,  167.98807405,  169.70245524,
#         168.64338738,  181.3085884 ,  178.94258469,  171.46358305,
#         165.75588172,  178.0741995 ,  150.03369556,  171.09311209,
#         162.30775903,  170.72532073,  173.18316319,  158.62642964,
#         169.11309525,  169.08467124,  167.09119587,  175.34736065,
#         165.65907476,  165.68687569,  166.77602514,  165.77490547,
#         175.1718545 ,  172.7436581 ,  161.73320553,  172.65607154,
#         182.44449426,  181.34228164,  184.79008074,  169.79906297,
#         180.05303057,  161.60529026,  170.07875074,  185.84050757,
#         172.3498802 ,  160.73150005,  188.49241587,  167.22435267,
#         170.86215123,  169.73558745,  168.76654862,  172.77111374,
#         166.77925132,  174.74603445,  161.28569831,  180.36938788,
#         160.05941369,  177.60487718,  169.43889748,  171.52549393,
#         170.62024029,  159.96532342,  152.00175525,  168.23187549,
#         164.22003435,  178.60255109,  162.63941803,  170.5825779 ,
#         178.86698117,  170.82828465,  174.76504789,  165.7820754 ,
#         169.14426301,  189.78885036,  155.60352685,  168.74043269,
#         165.96879653,  175.83098852,  162.86469591,  172.14486451,
#         171.25235037,  172.06593211,  164.18996381,  162.76038583,
#         169.49455422,  163.89559566,  167.91929049,  180.88068344,
#         167.88509597,  155.30793402,  164.60635236,  169.4883641 ,
#         169.00956111,  180.74624011,  162.34587439,  172.40213525,
#         165.91188736,  163.08911176,  171.42237731,  167.55512943,
#         171.66243746,  159.30848701,  149.40254135,  169.38515979,
#         169.73905061,  187.66914772,  179.99333747,  165.77821058,
#         179.65543368,  164.97519278,  187.92003311,  184.45028554,
#         165.03879154,  180.38240628,  171.86759854,  179.63437947,
#         177.14871047,  178.00029265,  172.00187243,  183.31621559,
#         161.80364883,  182.73882152,  175.9593863 ,  172.3193502 ])

# %%
plt.figure(figsize=(15, 6))
plt.plot(Gross_Profit)
plt.show()

# %% [markdown]
# What is the maximum and what is the minimum gross profit value you obtained?

# %%
max(Gross_Profit)
# Out:
# 190.89406004921057

# %%
min(Gross_Profit)
# Out:
# 149.40254135303178

# %% [markdown]
# What is its mean and standard deviation?

# %%
Gross_Profit.mean()
# Out:
# 170.24730566094252

# %%
Gross_Profit.std()
# Out:
# 8.1011222520257924

# %% [markdown]
# Do you remember what a histogram is? Plot the gross profit data on a histogram. Use 20 bins directly to check the distribution of the data.

# %%
plt.figure(figsize=(10, 6));
plt.hist(Gross_Profit, bins = 20);
plt.show()

# %% [markdown]
# ************
